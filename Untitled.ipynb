# %%
import dlib

# %%
import face_recognition

# %%
image = face_recognition.load_image_file("test_image.jpg")

# %%
face_landmarks_list = face_recognition.face_landmarks(image)

# %%
face_landmarks_list
# Out:
# [{'chin': [(469, 403),
#    (465, 429),
#    (465, 455),
#    (467, 482),
#    (474, 506),
#    (487, 527),
#    (503, 546),
#    (520, 562),
#    (543, 569),
#    (566, 570),
#    (591, 559),
#    (613, 545),
#    (633, 526),
#    (647, 504),
#    (657, 479),
#    (663, 452),
#    (667, 425)],
#   'left_eyebrow': [(481, 367), (496, 357), (514, 357), (532, 363), (547, 374)],
#   'right_eyebrow': [(583, 380),
#    (603, 374),
#    (623, 373),
#    (642, 379),
#    (654, 394)],
#   'nose_bridge': [(564, 400), (562, 422), (561, 442), (559, 463)],
#   'nose_tip': [(535, 467), (544, 473), (554, 479), (566, 478), (577, 476)],
#   'left_eye': [(499, 394),
#    (511, 387),
#    (524, 390),
#    (535, 402),
#    (522, 402),
#    (508, 400)],
#   'right_eye': [(590, 410),
#    (604, 402),
#    (618, 404),
#    (629, 414),
#    (618, 417),
#    (604, 415)],
#   'top_lip': [(508, 490),
#    (524, 489),
#    (539, 490),
#    (550, 495),
#    (562, 495),
#    (578, 500),
#    (595, 505),
#    (587, 505),
#    (561, 504),
#    (548, 503),
#    (537, 500),
#    (514, 493)],
#   'bottom_lip': [(595, 505),
#    (574, 516),
#    (557, 519),
#    (544, 519),
#    (533, 515),
#    (520, 506),
#    (508, 490),
#    (514, 493),
#    (536, 500),
#    (547, 503),
#    (559, 504),
#    (587, 505)]},
#  {'chin': [(209, 369),
#    (211, 404),
#    (213, 439),
#    (218, 473),
#    (233, 503),
#    (259, 526),
#    (289, 544),
#    (321, 559),
#    (354, 563),
#    (384, 555),
#    (403, 531),
#    (418, 506),
#    (429, 479),
#    (437, 451),
#    (439, 423),
#    (439, 396),
#    (434, 370)],
#   'left_eyebrow': [(248, 337), (265, 320), (288, 312), (313, 313), (334, 325)],
#   'right_eyebrow': [(380, 328),
#    (396, 321),
#    (414, 322),
#    (428, 329),
#    (433, 345)],
#   'nose_bridge': [(361, 354), (365, 371), (369, 389), (373, 407)],
#   'nose_tip': [(335, 421), (350, 426), (366, 431), (377, 427), (386, 423)],
#   'left_eye': [(277, 358),
#    (290, 353),
#    (303, 353),
#    (317, 359),
#    (303, 359),
#    (290, 359)],
#   'right_eye': [(381, 363),
#    (395, 359),
#    (407, 359),
#    (417, 365),
#    (407, 365),
#    (395, 364)],
#   'top_lip': [(290, 462),
#    (318, 453),
#    (345, 450),
#    (360, 452),
#    (374, 450),
#    (391, 453),
#    (403, 461),
#    (395, 463),
#    (374, 458),
#    (360, 459),
#    (344, 458),
#    (297, 463)],
#   'bottom_lip': [(403, 461),
#    (390, 484),
#    (373, 494),
#    (358, 495),
#    (341, 494),
#    (315, 486),
#    (290, 462),
#    (297, 463),
#    (342, 483),
#    (358, 483),
#    (373, 480),
#    (395, 463)]},
#  {'chin': [(792, 62),
#    (793, 69),
#    (794, 75),
#    (796, 81),
#    (801, 86),
#    (807, 89),
#    (814, 90),
#    (821, 92),
#    (826, 91),
#    (829, 90),
#    (831, 87),
#    (833, 83),
#    (833, 79),
#    (834, 74),
#    (834, 70),
#    (832, 66),
#    (831, 62)],
#   'left_eyebrow': [(806, 58), (810, 56), (814, 54), (818, 54), (822, 55)],
#   'right_eyebrow': [(826, 56), (828, 55), (829, 54), (831, 54), (832, 56)],
#   'nose_bridge': [(825, 60), (826, 62), (828, 64), (830, 67)],
#   'nose_tip': [(823, 72), (826, 72), (828, 72), (829, 72), (830, 71)],
#   'left_eye': [(811, 62),
#    (814, 61),
#    (816, 61),
#    (818, 61),
#    (816, 62),
#    (814, 62)],
#   'right_eye': [(826, 61),
#    (828, 61),
#    (830, 61),
#    (830, 62),
#    (829, 62),
#    (828, 62)],
#   'top_lip': [(817, 79),
#    (822, 77),
#    (825, 76),
#    (827, 76),
#    (828, 76),
#    (829, 77),
#    (829, 79),
#    (828, 78),
#    (828, 78),
#    (827, 78),
#    (825, 78),
#    (819, 79)],
#   'bottom_lip': [(829, 79),
#    (829, 80),
#    (828, 81),
#    (826, 81),
#    (825, 81),
#    (821, 81),
#    (817, 79),
#    (819, 79),
#    (825, 79),
#    (827, 79),
#    (828, 78),
#    (828, 78)]}]

# %%
from PIL import Image, ImageDraw
import face_recognition
import numpy as np

# Load the jpg file into a numpy array
image = face_recognition.load_image_file("test_image.jpg")

# Find all facial features in all the faces in the image
face_landmarks_list = face_recognition.face_landmarks(image)

print("I found {} face(s) in this photograph.".format(len(face_landmarks_list)))

# Create a PIL imagedraw object so we can draw on the picture
img = np.zeros([810,1080,3],dtype=np.uint8)
pil_image = Image.fromarray(img)
d = ImageDraw.Draw(pil_image)

for face_landmarks in face_landmarks_list:

    # Print the location of each facial feature in this image
    for facial_feature in face_landmarks.keys():
        print("The {} in this face has the following points: {}".format(facial_feature, face_landmarks[facial_feature]))

    # Let's trace out each facial feature in the image with a line!
    for facial_feature in face_landmarks.keys():
        d.line(face_landmarks[facial_feature], width=5)

# Show the picture
pil_image.show()
# Out:
# I found 3 face(s) in this photograph.
# The chin in this face has the following points: [(469, 403), (465, 429), (465, 455), (467, 482), (474, 506), (487, 527), (503, 546), (520, 562), (543, 569), (566, 570), (591, 559), (613, 545), (633, 526), (647, 504), (657, 479), (663, 452), (667, 425)]
# The left_eyebrow in this face has the following points: [(481, 367), (496, 357), (514, 357), (532, 363), (547, 374)]
# The right_eyebrow in this face has the following points: [(583, 380), (603, 374), (623, 373), (642, 379), (654, 394)]
# The nose_bridge in this face has the following points: [(564, 400), (562, 422), (561, 442), (559, 463)]
# The nose_tip in this face has the following points: [(535, 467), (544, 473), (554, 479), (566, 478), (577, 476)]
# The left_eye in this face has the following points: [(499, 394), (511, 387), (524, 390), (535, 402), (522, 402), (508, 400)]
# The right_eye in this face has the following points: [(590, 410), (604, 402), (618, 404), (629, 414), (618, 417), (604, 415)]
# The top_lip in this face has the following points: [(508, 490), (524, 489), (539, 490), (550, 495), (562, 495), (578, 500), (595, 505), (587, 505), (561, 504), (548, 503), (537, 500), (514, 493)]
# The bottom_lip in this face has the following points: [(595, 505), (574, 516), (557, 519), (544, 519), (533, 515), (520, 506), (508, 490), (514, 493), (536, 500), (547, 503), (559, 504), (587, 505)]
# The chin in this face has the following points: [(209, 369), (211, 404), (213, 439), (218, 473), (233, 503), (259, 526), (289, 544), (321, 559), (354, 563), (384, 555), (403, 531), (418, 506), (429, 479), (437, 451), (439, 423), (439, 396), (434, 370)]
# The left_eyebrow in this face has the following points: [(248, 337), (265, 320), (288, 312), (313, 313), (334, 325)]
# The right_eyebrow in this face has the following points: [(380, 328), (396, 321), (414, 322), (428, 329), (433, 345)]
# The nose_bridge in this face has the following points: [(361, 354), (365, 371), (369, 389), (373, 407)]
# The nose_tip in this face has the following points: [(335, 421), (350, 426), (366, 431), (377, 427), (386, 423)]
# The left_eye in this face has the following points: [(277, 358), (290, 353), (303, 353), (317, 359), (303, 359), (290, 359)]
# The right_eye in this face has the following points: [(381, 363), (395, 359), (407, 359), (417, 365), (407, 365), (395, 364)]
# The top_lip in this face has the following points: [(290, 462), (318, 453), (345, 450), (360, 452), (374, 450), (391, 453), (403, 461), (395, 463), (374, 458), (360, 459), (344, 458), (297, 463)]
# The bottom_lip in this face has the following points: [(403, 461), (390, 484), (373, 494), (358, 495), (341, 494), (315, 486), (290, 462), (297, 463), (342, 483), (358, 483), (373, 480), (395, 463)]
# The chin in this face has the following points: [(792, 62), (793, 69), (794, 75), (796, 81), (801, 86), (807, 89), (814, 90), (821, 92), (826, 91), (829, 90), (831, 87), (833, 83), (833, 79), (834, 74), (834, 70), (832, 66), (831, 62)]
# The left_eyebrow in this face has the following points: [(806, 58), (810, 56), (814, 54), (818, 54), (822, 55)]
# The right_eyebrow in this face has the following points: [(826, 56), (828, 55), (829, 54), (831, 54), (832, 56)]
# The nose_bridge in this face has the following points: [(825, 60), (826, 62), (828, 64), (830, 67)]
# The nose_tip in this face has the following points: [(823, 72), (826, 72), (828, 72), (829, 72), (830, 71)]
# The left_eye in this face has the following points: [(811, 62), (814, 61), (816, 61), (818, 61), (816, 62), (814, 62)]
# The right_eye in this face has the following points: [(826, 61), (828, 61), (830, 61), (830, 62), (829, 62), (828, 62)]
# The top_lip in this face has the following points: [(817, 79), (822, 77), (825, 76), (827, 76), (828, 76), (829, 77), (829, 79), (828, 78), (828, 78), (827, 78), (825, 78), (819, 79)]
# The bottom_lip in this face has the following points: [(829, 79), (829, 80), (828, 81), (826, 81), (825, 81), (821, 81), (817, 79), (819, 79), (825, 79), (827, 79), (828, 78), (828, 78)]

# %%
face_landmarks_list
# Out:
# [{'chin': [(469, 403),
#    (465, 429),
#    (465, 455),
#    (467, 482),
#    (474, 506),
#    (487, 527),
#    (503, 546),
#    (520, 562),
#    (543, 569),
#    (566, 570),
#    (591, 559),
#    (613, 545),
#    (633, 526),
#    (647, 504),
#    (657, 479),
#    (663, 452),
#    (667, 425)],
#   'left_eyebrow': [(481, 367), (496, 357), (514, 357), (532, 363), (547, 374)],
#   'right_eyebrow': [(583, 380),
#    (603, 374),
#    (623, 373),
#    (642, 379),
#    (654, 394)],
#   'nose_bridge': [(564, 400), (562, 422), (561, 442), (559, 463)],
#   'nose_tip': [(535, 467), (544, 473), (554, 479), (566, 478), (577, 476)],
#   'left_eye': [(499, 394),
#    (511, 387),
#    (524, 390),
#    (535, 402),
#    (522, 402),
#    (508, 400)],
#   'right_eye': [(590, 410),
#    (604, 402),
#    (618, 404),
#    (629, 414),
#    (618, 417),
#    (604, 415)],
#   'top_lip': [(508, 490),
#    (524, 489),
#    (539, 490),
#    (550, 495),
#    (562, 495),
#    (578, 500),
#    (595, 505),
#    (587, 505),
#    (561, 504),
#    (548, 503),
#    (537, 500),
#    (514, 493)],
#   'bottom_lip': [(595, 505),
#    (574, 516),
#    (557, 519),
#    (544, 519),
#    (533, 515),
#    (520, 506),
#    (508, 490),
#    (514, 493),
#    (536, 500),
#    (547, 503),
#    (559, 504),
#    (587, 505)]},
#  {'chin': [(209, 369),
#    (211, 404),
#    (213, 439),
#    (218, 473),
#    (233, 503),
#    (259, 526),
#    (289, 544),
#    (321, 559),
#    (354, 563),
#    (384, 555),
#    (403, 531),
#    (418, 506),
#    (429, 479),
#    (437, 451),
#    (439, 423),
#    (439, 396),
#    (434, 370)],
#   'left_eyebrow': [(248, 337), (265, 320), (288, 312), (313, 313), (334, 325)],
#   'right_eyebrow': [(380, 328),
#    (396, 321),
#    (414, 322),
#    (428, 329),
#    (433, 345)],
#   'nose_bridge': [(361, 354), (365, 371), (369, 389), (373, 407)],
#   'nose_tip': [(335, 421), (350, 426), (366, 431), (377, 427), (386, 423)],
#   'left_eye': [(277, 358),
#    (290, 353),
#    (303, 353),
#    (317, 359),
#    (303, 359),
#    (290, 359)],
#   'right_eye': [(381, 363),
#    (395, 359),
#    (407, 359),
#    (417, 365),
#    (407, 365),
#    (395, 364)],
#   'top_lip': [(290, 462),
#    (318, 453),
#    (345, 450),
#    (360, 452),
#    (374, 450),
#    (391, 453),
#    (403, 461),
#    (395, 463),
#    (374, 458),
#    (360, 459),
#    (344, 458),
#    (297, 463)],
#   'bottom_lip': [(403, 461),
#    (390, 484),
#    (373, 494),
#    (358, 495),
#    (341, 494),
#    (315, 486),
#    (290, 462),
#    (297, 463),
#    (342, 483),
#    (358, 483),
#    (373, 480),
#    (395, 463)]},
#  {'chin': [(792, 62),
#    (793, 69),
#    (794, 75),
#    (796, 81),
#    (801, 86),
#    (807, 89),
#    (814, 90),
#    (821, 92),
#    (826, 91),
#    (829, 90),
#    (831, 87),
#    (833, 83),
#    (833, 79),
#    (834, 74),
#    (834, 70),
#    (832, 66),
#    (831, 62)],
#   'left_eyebrow': [(806, 58), (810, 56), (814, 54), (818, 54), (822, 55)],
#   'right_eyebrow': [(826, 56), (828, 55), (829, 54), (831, 54), (832, 56)],
#   'nose_bridge': [(825, 60), (826, 62), (828, 64), (830, 67)],
#   'nose_tip': [(823, 72), (826, 72), (828, 72), (829, 72), (830, 71)],
#   'left_eye': [(811, 62),
#    (814, 61),
#    (816, 61),
#    (818, 61),
#    (816, 62),
#    (814, 62)],
#   'right_eye': [(826, 61),
#    (828, 61),
#    (830, 61),
#    (830, 62),
#    (829, 62),
#    (828, 62)],
#   'top_lip': [(817, 79),
#    (822, 77),
#    (825, 76),
#    (827, 76),
#    (828, 76),
#    (829, 77),
#    (829, 79),
#    (828, 78),
#    (828, 78),
#    (827, 78),
#    (825, 78),
#    (819, 79)],
#   'bottom_lip': [(829, 79),
#    (829, 80),
#    (828, 81),
#    (826, 81),
#    (825, 81),
#    (821, 81),
#    (817, 79),
#    (819, 79),
#    (825, 79),
#    (827, 79),
#    (828, 78),
#    (828, 78)]}]
